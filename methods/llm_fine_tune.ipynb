# %%
import os
import sys

sys.path.insert(0, os.path.dirname(os.getcwd()))

# %%
from data_preparation.preprocess_data import preprocess_data

df = preprocess_data()
# Out:
# Loading dataset...
# Cleaning data...

# %%
from data_preparation.preprocess_data import make_splits

for split in make_splits(df):
    train, val, test = split['train'], split['val'], split['test']
    # train on train, eval on val, final test on test
# Out:
# dict_keys(['train', 'val', 'test'])
# {'train': 450113, 'val': 96453, 'test': 273283}
# dict_keys(['train', 'val', 'test'])
# {'train': 450113, 'val': 96453, 'test': 273283}
# dict_keys(['train', 'val', 'test'])
# {'train': 450113, 'val': 96453, 'test': 273283}
